# %% [markdown]
# Read Google Mobility Report File

# %%
mobility_url = 'https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv'

mobility = pd.read_csv(mobiltiy_url,
                     parse_dates=['date'],
                     index_col=['country_region', 'date'],
                     squeeze=True).sort_index()

# %%
#Filter out subregions 

mobility = mobiltiy[mobiltiy['sub_region_1'].isnull()]

# %%
mobiltiy
# Out:
#                           country_region_code sub_region_1 sub_region_2  retail_and_recreation_percent_change_from_baseline  grocery_and_pharmacy_percent_change_from_baseline  parks_percent_change_from_baseline  transit_stations_percent_change_from_baseline  workplaces_percent_change_from_baseline  residential_percent_change_from_baseline
# country_region date
# Afghanistan    2020-02-15                  AF          NaN          NaN                                               -9.0                                               -10.0                                 0.0                                           -2.0                                    -28.0                                       5.0
#                2020-02-16                  AF          NaN          NaN                                                3.0                                                11.0                                 1.0                                           10.0                                      4.0                                       0.0
#                2020-02-17                  AF          NaN          NaN                                                6.0                                                11.0                                 2.0                                            9.0                                      5.0                                      -1.0
#                2020-02-18                  AF          NaN          NaN                                                3.0                                                 5.0                                 3.0                                            9.0                                      6.0                                      -1.0
#                2020-02-19                  AF          NaN          NaN                                               -1.0                                                 3.0                                 1.0                                            0.0                                      5.0                                       1.0
# ...                                       ...          ...          ...                                                ...                                                 ...                                 ...                                            ...                                      ...                                       ...
# Zimbabwe       2020-04-07                  ZW          NaN          NaN                                              -64.0                                               -52.0                               -49.0                                          -78.0                                    -67.0                                      42.0
#                2020-04-08                  ZW          NaN          NaN                                              -62.0                                               -51.0                               -51.0                                          -78.0                                    -66.0                                      41.0
#                2020-04-09                  ZW          NaN          NaN                                              -60.0                                               -47.0                               -47.0                                          -77.0                                    -66.0                                      41.0
#                2020-04-10                  ZW          NaN          NaN                                              -70.0                                               -57.0                               -53.0                                          -82.0                                    -78.0                                      48.0
#                2020-04-11                  ZW          NaN          NaN                                              -69.0                                               -56.0                               -48.0                                          -81.0                                    -58.0                                      36.0
#
# [7467 rows x 9 columns]

# %% [markdown]
# Now we read the Rt file

# %%
rt_uri = 'data/rt-latest.csv'

rt = pd.read_csv(rt_uri,
                     usecols=[0,1,2,3,4,5,6],
                     parse_dates=['date'],
                     #index_col=['location', 'date'],
                     squeeze=True)

# %%
mergedRtMobility  = rt.merge(mobility,left_on=['location','date'],right_on=['country_region','date'])


mergedRtMobility.to_csv('data/merged-rt-mobility.csv')
